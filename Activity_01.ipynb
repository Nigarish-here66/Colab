# %%
numbers = [1,2,3,4,5]
for item in numbers:
  print (item)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
numbers = [1,2,3,4,5]
i = 0
while i < len(numbers):
  print (numbers[i])
  i = i+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
numbers = [1,2,3,4,5]
numbers.append(6)
numbers.insert(0,-1)
print (numbers)
# Out:
# [-1, 1, 2, 3, 4, 5, 6]

# %%
names = ["nigarish","manahil","esha","rahat","aiza"]
print (names[-1])
names [4] = "aroosa"
print (names)
print (names[0:3])
# Out:
# aiza
# ['nigarish', 'manahil', 'esha', 'rahat', 'aroosa']
# ['nigarish', 'manahil', 'esha']

# %%
temp = 35
if temp > 30:
  print ("It's Hot")
elif temp > 20:
  print ("It's Mild")
else:
  print ("It's Cold")
# Out:
# It's Hot
