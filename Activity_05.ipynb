# %% [markdown]
# **Tensor Flow:** An open-source library for numerical computation, often used for machine learning tasks.

# %% [markdown]
# **Karas:** A high-level API in Tensor Flow that simplifies building and training neural networks.

# %% [markdown]
# ## Dataset consisting a single input layer with 5 floating point values

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import SGD

# Generate dataset
X = np.random.rand(100, 5)
Y = np.random.rand(100, 5)

# %% [markdown]
# ## Use dense and sequential keywords for making the model

# %%
model = Sequential([
    Dense(5, input_dim=5, activation='linear')
])

# %% [markdown]
# ## Train this neural network with MSE and SGD for 50 epoches

# %%
# Compile the model
model.compile(optimizer=SGD(learning_rate=0.01), loss='mse')

# Train the model
model.fit(X, Y, epochs=50, batch_size=10)

# Evaluate on the same data
loss = model.evaluate(X, Y)
print(f"Final Loss: {loss}")
# Out:
# Epoch 1/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3764
# Epoch 2/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3458
# Epoch 3/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3106
# Epoch 4/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3093
# Epoch 5/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2758
# Epoch 6/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2612
# Epoch 7/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2333
# Epoch 8/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2266
# Epoch 9/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2233
# Epoch 10/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2042
# Epoch 11/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2026
# Epoch 12/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1802
# Epoch 13/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2008
# Epoch 14/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1662
# Epoch 15/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1821
# Epoch 16/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1698
# Epoch 17/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1747
# Epoch 18/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1675
# Epoch 19/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1603
# Epoch 20/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1608
# Epoch 21/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1687
# Epoch 22/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1539
# Epoch 23/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1538
# Epoch 24/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1449
# Epoch 25/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1588
# Epoch 26/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1554
# Epoch 27/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1488
# Epoch 28/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1505
# Epoch 29/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1537
# Epoch 30/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1522
# Epoch 31/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1503
# Epoch 32/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1580
# Epoch 33/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1388
# Epoch 34/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1417
# Epoch 35/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1423
# Epoch 36/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1362
# Epoch 37/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1447
# Epoch 38/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1513
# Epoch 39/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1432
# Epoch 40/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1421
# Epoch 41/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1396
# Epoch 42/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1401
# Epoch 43/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1298
# Epoch 44/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1394
# Epoch 45/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1371
# Epoch 46/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1404
# Epoch 47/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1424
# Epoch 48/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1465
# Epoch 49/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1420
# Epoch 50/50
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1445
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1380
# Final Loss: 0.13891436159610748

# %% [markdown]
# ## Predict value of 6.0 out of trained mode

# %%
# Input for prediction
new_input = np.array([[6.0, 6.0, 6.0, 6.0, 6.0]])

# Predict output
predicted_output = model.predict(new_input)

print("Predicted output:", predicted_output)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# Predicted output: [[4.9497943 6.3594165 1.7716775 2.6373618 5.022699 ]]
